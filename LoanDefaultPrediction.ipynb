# %% [markdown]
# ## Introduction
#
# In this challenge, you'll get the opportunity to tackle one of the most industry-relevant machine learning problems with a unique dataset that will put your modeling skills to the test. Financial loan services are leveraged by companies across many industries, from big banks to financial institutions to government loans. One of the primary objectives of companies with financial loan services is to decrease payment defaults and ensure that individuals are paying back their loans as expected. In order to do this efficiently and systematically, many companies employ machine learning to predict which individuals are at the highest risk of defaulting on their loans, so that proper interventions can be effectively deployed to the right audience.
#
# In this challenge, we will be tackling the loan default prediction problem on a very unique and interesting group of individuals who have taken financial loans.
#
# Imagine that you are a new data scientist at a major financial institution and you are tasked with building a model that can predict which individuals will default on their loan payments. We have provided a dataset that is a sample of individuals who received loans in 2021.
#
# This financial institution has a vested interest in understanding the likelihood of each individual to default on their loan payments so that resources can be allocated appropriately to support these borrowers. In this challenge, you will use your machine learning toolkit to do just that!

# %% [markdown]
# ## Import Python Modules
#
# First, import the primary modules that will be used in this project. Remember as this is an open-ended project please feel free to make use of any of your favorite libraries that you feel may be useful for this challenge. For example some of the following popular packages may be useful:
#
# - pandas
# - numpy
# - Scipy
# - Scikit-learn
# - keras
# - maplotlib
# - seaborn
# - etc, etc

# %%
# Import required packages

# Data packages
import pandas as pd
import numpy as np

# Machine Learning / Classification packages
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn.dummy import DummyClassifier

# Visualization Packages
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Import any other packages you may want to use

# %% [markdown]
# ## Load the Data
#
# Let's start by loading the dataset `train.csv` into a dataframe `train_df`, and `test.csv` into a dataframe `test_df` and display the shape of the dataframes.

# %%
train_df = pd.read_csv("train.csv")
print('train_df Shape:', train_df.shape)
train_df.head()

# %% [markdown]
# ## Explore, Clean, Validate, and Visualize the Data (optional)
#
# Feel free to explore, clean, validate, and visualize the data however you see fit for this competition to help determine or optimize your predictive model. Please note - the final autograding will only be on the accuracy of the `prediction_df` predictions.

# %%
# your code here (optional)

# %%
df=pd.read_csv("train.csv")
df.head()
# Out:
#        LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 0  I38PQUQS96   56   85994       50587          520              80
# 1  HPSK72WA7R   69   50432      124440          458              15
# 2  C1OZ6DPJ8Y   46   84208      129188          451              26
# 3  V2KKSFM3UN   32   31713       44799          743               0
# 4  EY08JDHTZP   60   20437        9139          633               8
#
#    NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# 0               4         15.23        36      0.44   Bachelor's
# 1               1          4.81        60      0.68     Master's
# 2               3         21.17        24      0.31     Master's
# 3               3          7.07        24      0.23  High School
# 4               4          6.51        48      0.73   Bachelor's
#
#   EmploymentType MaritalStatus HasMortgage HasDependents LoanPurpose  \
# 0      Full-time      Divorced         Yes           Yes       Other
# 1      Full-time       Married          No            No       Other
# 2     Unemployed      Divorced         Yes           Yes        Auto
# 3      Full-time       Married          No            No    Business
# 4     Unemployed      Divorced          No           Yes        Auto
#
#   HasCoSigner  Default
# 0         Yes        0
# 1         Yes        0
# 2          No        1
# 3          No        0
# 4          No        0

# %%
onehot_columns=['Education', 'EmploymentType', 'MaritalStatus',
       'HasMortgage', 'HasDependents', 'LoanPurpose', 'HasCoSigner']

# %%
onehot_df=pd.get_dummies(df[onehot_columns],dtype=int)

# %%
onehot_df.drop(['HasMortgage_No','HasDependents_No','HasCoSigner_No'],axis=1,inplace=True)

# %%
df.drop(onehot_columns,axis=1,inplace=True)

# %%
df.drop(["LoanID"],axis=1,inplace=True)

# %%
df2=pd.concat([df,onehot_df],axis=1)
df2.head()
# Out:
#    Age  Income  LoanAmount  CreditScore  MonthsEmployed  NumCreditLines  \
# 0   56   85994       50587          520              80               4
# 1   69   50432      124440          458              15               1
# 2   46   84208      129188          451              26               3
# 3   32   31713       44799          743               0               3
# 4   60   20437        9139          633               8               4
#
#    InterestRate  LoanTerm  DTIRatio  Default  ...  MaritalStatus_Married  \
# 0         15.23        36      0.44        0  ...                      0
# 1          4.81        60      0.68        0  ...                      1
# 2         21.17        24      0.31        1  ...                      0
# 3          7.07        24      0.23        0  ...                      1
# 4          6.51        48      0.73        0  ...                      0
#
#    MaritalStatus_Single  HasMortgage_Yes  HasDependents_Yes  LoanPurpose_Auto  \
# 0                     0                1                  1                 0
# 1                     0                0                  0                 0
# 2                     0                1                  1                 1
# 3                     0                0                  0                 0
# 4                     0                0                  1                 1
#
#    LoanPurpose_Business  LoanPurpose_Education  LoanPurpose_Home  \
# 0                     0                      0                 0
# 1                     0                      0                 0
# 2                     0                      0                 0
# 3                     1                      0                 0
# 4                     0                      0                 0
#
#    LoanPurpose_Other  HasCoSigner_Yes
# 0                  1                1
# 1                  1                1
# 2                  0                0
# 3                  0                0
# 4                  0                0
#
# [5 rows x 29 columns]

# %% [markdown]
# outlier_col=["DTIRatio","InterestRate","CreditScore","LoanAmount","Income"]

# %%
scal_col=['Age', 'Income', 'LoanAmount', 'CreditScore',
       'MonthsEmployed', 'NumCreditLines', 'InterestRate', 'LoanTerm',
       'DTIRatio']

# %%
from sklearn.preprocessing import StandardScaler

# %%
# Standart Scaler uygulama
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df2[scal_col])

# Ölçeklendirilmiş veri setini DataFrame olarak oluşturma
scaled_df = pd.DataFrame(scaled_data, columns=scal_col)

scaled_df.head()
# Out:
#         Age    Income  LoanAmount  CreditScore  MonthsEmployed  \
# 0  0.833990  0.089693   -1.086833    -0.341492        0.590533
# 1  1.701221 -0.823021   -0.044309    -0.731666       -1.285731
# 2  0.166888  0.043854    0.022715    -0.775718       -0.968209
# 3 -0.767053 -1.303452   -1.168538     1.061875       -1.718715
# 4  1.100830 -1.592855   -1.671921     0.369631       -1.487790
#
#    NumCreditLines  InterestRate  LoanTerm  DTIRatio
# 0        1.341937      0.261771 -0.001526 -0.260753
# 1       -1.343791     -1.308350  1.412793  0.778585
# 2        0.446694      1.156831 -0.708685 -0.823728
# 3        0.446694     -0.967805 -0.708685 -1.170174
# 4        1.341937     -1.052188  0.705634  0.995114

# %%
droped_df2=df2.drop(scal_col,axis=1)
droped_df2.head(1)
# Out:
#    Default  Education_Bachelor's  Education_High School  Education_Master's  \
# 0        0                     1                      0                   0
#
#    Education_PhD  EmploymentType_Full-time  EmploymentType_Part-time  \
# 0              0                         1                         0
#
#    EmploymentType_Self-employed  EmploymentType_Unemployed  \
# 0                             0                          0
#
#    MaritalStatus_Divorced  MaritalStatus_Married  MaritalStatus_Single  \
# 0                       1                      0                     0
#
#    HasMortgage_Yes  HasDependents_Yes  LoanPurpose_Auto  LoanPurpose_Business  \
# 0                1                  1                 0                     0
#
#    LoanPurpose_Education  LoanPurpose_Home  LoanPurpose_Other  HasCoSigner_Yes
# 0                      0                 0                  1                1

# %%
df3=pd.concat([scaled_df,droped_df2],axis=1)
df3.head()
# Out:
#         Age    Income  LoanAmount  CreditScore  MonthsEmployed  \
# 0  0.833990  0.089693   -1.086833    -0.341492        0.590533
# 1  1.701221 -0.823021   -0.044309    -0.731666       -1.285731
# 2  0.166888  0.043854    0.022715    -0.775718       -0.968209
# 3 -0.767053 -1.303452   -1.168538     1.061875       -1.718715
# 4  1.100830 -1.592855   -1.671921     0.369631       -1.487790
#
#    NumCreditLines  InterestRate  LoanTerm  DTIRatio  Default  ...  \
# 0        1.341937      0.261771 -0.001526 -0.260753        0  ...
# 1       -1.343791     -1.308350  1.412793  0.778585        0  ...
# 2        0.446694      1.156831 -0.708685 -0.823728        1  ...
# 3        0.446694     -0.967805 -0.708685 -1.170174        0  ...
# 4        1.341937     -1.052188  0.705634  0.995114        0  ...
#
#    MaritalStatus_Married  MaritalStatus_Single  HasMortgage_Yes  \
# 0                      0                     0                1
# 1                      1                     0                0
# 2                      0                     0                1
# 3                      1                     0                0
# 4                      0                     0                0
#
#    HasDependents_Yes  LoanPurpose_Auto  LoanPurpose_Business  \
# 0                  1                 0                     0
# 1                  0                 0                     0
# 2                  1                 1                     0
# 3                  0                 0                     1
# 4                  1                 1                     0
#
#    LoanPurpose_Education  LoanPurpose_Home  LoanPurpose_Other  HasCoSigner_Yes
# 0                      0                 0                  1                1
# 1                      0                 0                  1                1
# 2                      0                 0                  0                0
# 3                      0                 0                  0                0
# 4                      0                 0                  0                0
#
# [5 rows x 29 columns]

# %% [markdown]
# ### Example prediction submission:
#
# The code below is a very naive prediction method that simply predicts loan defaults using a Dummy Classifier. This is used as just an example showing the submission format required. Please change/alter/delete this code below and create your own improved prediction methods for generating `prediction_df`.

# %%
x=df3.drop(["Default"],axis=1)
y=df3["Default"]
print(y)
x.head()
# Out:
# 0         0
# 1         0
# 2         1
# 3         0
# 4         0
#          ..
# 255342    0
# 255343    1
# 255344    0
# 255345    0
# 255346    0
# Name: Default, Length: 255347, dtype: int64
#         Age    Income  LoanAmount  CreditScore  MonthsEmployed  \
# 0  0.833990  0.089693   -1.086833    -0.341492        0.590533
# 1  1.701221 -0.823021   -0.044309    -0.731666       -1.285731
# 2  0.166888  0.043854    0.022715    -0.775718       -0.968209
# 3 -0.767053 -1.303452   -1.168538     1.061875       -1.718715
# 4  1.100830 -1.592855   -1.671921     0.369631       -1.487790
#
#    NumCreditLines  InterestRate  LoanTerm  DTIRatio  Education_Bachelor's  \
# 0        1.341937      0.261771 -0.001526 -0.260753                     1
# 1       -1.343791     -1.308350  1.412793  0.778585                     0
# 2        0.446694      1.156831 -0.708685 -0.823728                     0
# 3        0.446694     -0.967805 -0.708685 -1.170174                     0
# 4        1.341937     -1.052188  0.705634  0.995114                     1
#
#    ...  MaritalStatus_Married  MaritalStatus_Single  HasMortgage_Yes  \
# 0  ...                      0                     0                1
# 1  ...                      1                     0                0
# 2  ...                      0                     0                1
# 3  ...                      1                     0                0
# 4  ...                      0                     0                0
#
#    HasDependents_Yes  LoanPurpose_Auto  LoanPurpose_Business  \
# 0                  1                 0                     0
# 1                  0                 0                     0
# 2                  1                 1                     0
# 3                  0                 0                     1
# 4                  1                 1                     0
#
#    LoanPurpose_Education  LoanPurpose_Home  LoanPurpose_Other  HasCoSigner_Yes
# 0                      0                 0                  1                1
# 1                      0                 0                  1                1
# 2                      0                 0                  0                0
# 3                      0                 0                  0                0
# 4                      0                 0                  0                0
#
# [5 rows x 28 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
# Veri setini eğitim ve test olarak ayırma
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# # Load trained model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, InputLayer
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Sinir ağı modeli oluşturma
model = Sequential()
model.add(InputLayer(input_shape=(X_train.shape[1],)))
model.add(Dense(64, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(32, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(16, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

# %%
# Optimizer tanımlama (learning rate ve momentum ile)
optimizer = SGD(learning_rate=0.01, momentum=0.9)

# %%
# Modeli derleme
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Erken durdurma callback'i
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# %%
# Modeli eğitme
model.fit(X_train, y_train, epochs=35, batch_size=10, validation_data=(X_test, y_test), callbacks=[early_stopping])
# Out:
# Train on 204277 samples, validate on 51070 samples
# Epoch 1/35
# 204277/204277 [==============================] - 41s 203us/sample - loss: 0.3303 - accuracy: 0.8832 - val_loss: 0.3164 - val_accuracy: 0.8846
# Epoch 2/35
# 204277/204277 [==============================] - 41s 201us/sample - loss: 0.3302 - accuracy: 0.8833 - val_loss: 0.3136 - val_accuracy: 0.8852
# Epoch 3/35
# 204277/204277 [==============================] - 39s 191us/sample - loss: 0.3296 - accuracy: 0.8833 - val_loss: 0.3120 - val_accuracy: 0.8853
# Epoch 4/35
# 204277/204277 [==============================] - 37s 181us/sample - loss: 0.3293 - accuracy: 0.8833 - val_loss: 0.3116 - val_accuracy: 0.8862
# Epoch 5/35
# 204277/204277 [==============================] - 38s 186us/sample - loss: 0.3285 - accuracy: 0.8834 - val_loss: 0.3164 - val_accuracy: 0.8845
# Epoch 6/35
# 204277/204277 [==============================] - 38s 187us/sample - loss: 0.3282 - accuracy: 0.8832 - val_loss: 0.3140 - val_accuracy: 0.8849
# Epoch 7/35
# 204277/204277 [==============================] - 38s 185us/sample - loss: 0.3283 - accuracy: 0.8833 - val_loss: 0.3175 - val_accuracy: 0.8845
# Epoch 8/35
# 204277/204277 [==============================] - 39s 189us/sample - loss: 0.3285 - accuracy: 0.8834 - val_loss: 0.3102 - val_accuracy: 0.8876
# Epoch 9/35
# 204277/204277 [==============================] - 37s 183us/sample - loss: 0.3289 - accuracy: 0.8833 - val_loss: 0.3113 - val_accuracy: 0.8859
# Epoch 10/35
# 204277/204277 [==============================] - 38s 187us/sample - loss: 0.3279 - accuracy: 0.8831 - val_loss: 0.3145 - val_accuracy: 0.8853
# Epoch 11/35
# 204277/204277 [==============================] - 39s 188us/sample - loss: 0.3281 - accuracy: 0.8834 - val_loss: 0.3120 - val_accuracy: 0.8853
# Epoch 12/35
# 204277/204277 [==============================] - 38s 185us/sample - loss: 0.3282 - accuracy: 0.8833 - val_loss: 0.3101 - val_accuracy: 0.8867
# Epoch 13/35
# 204277/204277 [==============================] - 37s 182us/sample - loss: 0.3287 - accuracy: 0.8833 - val_loss: 0.3143 - val_accuracy: 0.8849
# Epoch 14/35
# 204277/204277 [==============================] - 36s 175us/sample - loss: 0.3280 - accuracy: 0.8834 - val_loss: 0.3115 - val_accuracy: 0.8856
# Epoch 15/35
# 204277/204277 [==============================] - 36s 177us/sample - loss: 0.3278 - accuracy: 0.8833 - val_loss: 0.3120 - val_accuracy: 0.8866
# Epoch 16/35
# 204277/204277 [==============================] - 36s 176us/sample - loss: 0.3282 - accuracy: 0.8832 - val_loss: 0.3101 - val_accuracy: 0.8877
# Epoch 17/35
# 204277/204277 [==============================] - 36s 178us/sample - loss: 0.3278 - accuracy: 0.8834 - val_loss: 0.3101 - val_accuracy: 0.8875
# Epoch 18/35
# 204277/204277 [==============================] - 36s 175us/sample - loss: 0.3277 - accuracy: 0.8834 - val_loss: 0.3114 - val_accuracy: 0.8856
# Epoch 19/35
# 204277/204277 [==============================] - 36s 176us/sample - loss: 0.3276 - accuracy: 0.8832 - val_loss: 0.3103 - val_accuracy: 0.8869
# Epoch 20/35
# 204277/204277 [==============================] - 36s 175us/sample - loss: 0.3270 - accuracy: 0.8833 - val_loss: 0.3139 - val_accuracy: 0.8852
# Epoch 21/35
# 204277/204277 [==============================] - 36s 177us/sample - loss: 0.3275 - accuracy: 0.8832 - val_loss: 0.3115 - val_accuracy: 0.8861
# Epoch 22/35
# 204277/204277 [==============================] - 36s 176us/sample - loss: 0.3269 - accuracy: 0.8832 - val_loss: 0.3099 - val_accuracy: 0.8878
# Epoch 23/35
# 204277/204277 [==============================] - 36s 176us/sample - loss: 0.3279 - accuracy: 0.8834 - val_loss: 0.3108 - val_accuracy: 0.8862
# Epoch 24/35
# 204277/204277 [==============================] - 36s 176us/sample - loss: 0.3274 - accuracy: 0.8834 - val_loss: 0.3105 - val_accuracy: 0.8871
# Epoch 25/35
# 204277/204277 [==============================] - 37s 181us/sample - loss: 0.3272 - accuracy: 0.8835 - val_loss: 0.3101 - val_accuracy: 0.8875
# Epoch 26/35
# 204277/204277 [==============================] - 36s 176us/sample - loss: 0.3267 - accuracy: 0.8833 - val_loss: 0.3105 - val_accuracy: 0.8865
# Epoch 27/35
# 204277/204277 [==============================] - 36s 174us/sample - loss: 0.3270 - accuracy: 0.8833 - val_loss: 0.3108 - val_accuracy: 0.8874
# Epoch 28/35
# 204277/204277 [==============================] - 36s 177us/sample - loss: 0.3265 - accuracy: 0.8833 - val_loss: 0.3146 - val_accuracy: 0.8853
# Epoch 29/35
# 204277/204277 [==============================] - 36s 175us/sample - loss: 0.3270 - accuracy: 0.8833 - val_loss: 0.3121 - val_accuracy: 0.8857
# Epoch 30/35
# 204277/204277 [==============================] - 36s 176us/sample - loss: 0.3268 - accuracy: 0.8834 - val_loss: 0.3129 - val_accuracy: 0.8852
# Epoch 31/35
# 204277/204277 [==============================] - 37s 180us/sample - loss: 0.3269 - accuracy: 0.8833 - val_loss: 0.3100 - val_accuracy: 0.8872
# Epoch 32/35
# 204277/204277 [==============================] - 36s 178us/sample - loss: 0.3272 - accuracy: 0.8832 - val_loss: 0.3123 - val_accuracy: 0.8851

# %%
# Modelin performansını değerlendirme
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Loss: {loss}, Accuracy: {accuracy}')
# Out:
# 51070/51070 [==============================] - 1s 23us/sample - loss: 0.3099 - accuracy: 0.8878
# Loss: 0.30992395734166084, Accuracy: 0.8878010511398315

# %%
# Modeli kaydetme (HDF5 formatında)
model.save('model_with_momentum.h5')

# Skalerı kaydetme
import pickle
with open('scaler_with_momentum.pkl', 'wb') as file:
    pickle.dump(scaler, file)

# %%
from sklearn.metrics import classification_report,roc_auc_score

# %%
from sklearn.metrics import classification_report, roc_auc_score
import numpy as np

# Modelin predict yöntemi ile tahmin yapma
predictions = model.predict(X_test)
binary_predictions = np.where(predictions > 0.5, 1, 0)

# Sınıflandırma raporunu oluşturma
report = classification_report(y_test, binary_predictions)
print("Sınıflandırma Raporu:\n", report)

# ROC AUC puanını hesaplama
roc_auc = roc_auc_score(y_test, predictions)
print("ROC AUC Puanı:", roc_auc)
# Out:
# Sınıflandırma Raporu:
#                precision    recall  f1-score   support
#
#            0       0.89      0.99      0.94     45170
#            1       0.62      0.07      0.13      5900
#
#     accuracy                           0.89     51070
#    macro avg       0.76      0.53      0.54     51070
# weighted avg       0.86      0.89      0.85     51070
#
# ROC AUC Puanı: 0.7591789360720143

# %%
# Out:
#              Age    Income  LoanAmount  CreditScore  MonthsEmployed  \
# 137187 -1.700995  1.413566    1.151277     1.710067       -0.968209
# 230334  0.233598 -0.649471   -1.716656     1.093340       -0.852747
# 19687  -1.167314  0.046934   -0.458972    -0.763132       -1.516656
# 106509  0.633859 -0.839370    1.439897    -0.259682        1.369905
# 242291  0.367019  0.845693   -1.489357     1.672308       -1.718715
#
#         NumCreditLines  InterestRate  LoanTerm  DTIRatio  \
# 137187       -0.448549     -0.455482  1.412793  1.341560
# 230334       -0.448549      0.938340 -0.001526  0.995114
# 19687        -0.448549      1.620936 -1.415845 -0.217447
# 106509        0.446694      0.142731  1.412793 -1.430008
# 242291        1.341937      1.655593 -1.415845 -1.689843
#
#         Education_Bachelor's  ...  MaritalStatus_Married  \
# 137187                     0  ...                      0
# 230334                     0  ...                      0
# 19687                      0  ...                      1
# 106509                     1  ...                      0
# 242291                     1  ...                      0
#
#         MaritalStatus_Single  HasMortgage_Yes  HasDependents_Yes  \
# 137187                     1                1                  0
# 230334                     0                0                  1
# 19687                      0                0                  0
# 106509                     1                1                  0
# 242291                     1                0                  1
#
#         LoanPurpose_Auto  LoanPurpose_Business  LoanPurpose_Education  \
# 137187                 0                     1                      0
# 230334                 0                     0                      1
# 19687                  0                     0                      0
# 106509                 1                     0                      0
# 242291                 0                     0                      1
#
#         LoanPurpose_Home  LoanPurpose_Other  HasCoSigner_Yes
# 137187                 0                  0                0
# 230334                 0                  0                0
# 19687                  0                  1                1
# 106509                 0                  0                1
# 242291                 0                  0                1
#
# [5 rows x 28 columns]
